# %% [markdown]
# <a href="https://colab.research.google.com/github/shruti123-web/INTM584_IES_/blob/main/INTM584_IES_Lec6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Supermarket_sales  Copy.csv")
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.iloc[3,7]=df.Unitprice.mean()

# %%
df.head(10)
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
# 5   6  699-14-3026      C  Naypyitaw       Normal    Male
# 6   7  355-53-5943      A     Yangon       Member  Female
# 7   8  315-22-5665      C  Naypyitaw       Normal  Female
# 8   9  665-32-9167      A     Yangon       Member  Female
# 9  10  692-92-5582      B   Mandalay       Member  Female
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty  74.690000         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories  15.280000         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle  46.330000         7  16.2155  340.5255   3/3/2019
# ...

# %%
for i in range(len(df.Unitprice)):
  if(pd.isnull(df.iloc[i,7])):
    df.iloc[i,7]=(df.Unitprice.mean())

# %%
#for i in range(len(df)):
  #if((pd.isnull(df.iloc[i,7]))):
    #df.iloc[i,7]=df.Unitprice.mean()

#a = pd.isnull(df["Unitprice"])
#a

# %%
df.head(20)
# Out:
#     No    InvoiceID Branch       City Customertype  Gender  \
# 0    1  750-67-8428      A     Yangon       Member  Female
# 1    2  226-31-3081      C  Naypyitaw       Normal  Female
# 2    3  631-41-3108      A     Yangon       Normal    Male
# 3    4  123-19-1176      A     Yangon       Member    Male
# 4    5  373-73-7910      A     Yangon       Normal    Male
# 5    6  699-14-3026      C  Naypyitaw       Normal    Male
# 6    7  355-53-5943      A     Yangon       Member  Female
# 7    8  315-22-5665      C  Naypyitaw       Normal  Female
# 8    9  665-32-9167      A     Yangon       Member  Female
# 9   10  692-92-5582      B   Mandalay       Member  Female
# 10  11  351-62-0822      B   Mandalay       Member  Female
# 11  12  529-56-3974      B   Mandalay       Member    Male
# 12  13  365-64-0515      A     Yangon       Normal  Female
# 13  14  252-56-2699      A     Yangon       Normal    Male
# 14  15  829-34-3910      A     Yangon       Normal  Female
# ...

# %%
#df.Unitprice.fillna(df.Unitprice.mean())
df.Unitprice.fillna(df.Unitprice.mean() , inplace=True)

# %%
df.head(20)
# Out:
#     No    InvoiceID Branch       City Customertype  Gender  \
# 0    1  750-67-8428      A     Yangon       Member  Female
# 1    2  226-31-3081      C  Naypyitaw       Normal  Female
# 2    3  631-41-3108      A     Yangon       Normal    Male
# 3    4  123-19-1176      A     Yangon       Member    Male
# 4    5  373-73-7910      A     Yangon       Normal    Male
# 5    6  699-14-3026      C  Naypyitaw       Normal    Male
# 6    7  355-53-5943      A     Yangon       Member  Female
# 7    8  315-22-5665      C  Naypyitaw       Normal  Female
# 8    9  665-32-9167      A     Yangon       Member  Female
# 9   10  692-92-5582      B   Mandalay       Member  Female
# 10  11  351-62-0822      B   Mandalay       Member  Female
# 11  12  529-56-3974      B   Mandalay       Member    Male
# 12  13  365-64-0515      A     Yangon       Normal  Female
# 13  14  252-56-2699      A     Yangon       Normal    Male
# 14  15  829-34-3910      A     Yangon       Normal  Female
# ...

# %%
df.describe() #summary
# Out:
#                 No    Unitprice     Quantity         Tax        Total  \
# count  1000.000000  1000.000000  1000.000000  995.000000  1000.000000
# mean    500.500000    55.595753     5.510000   15.338145   322.966749
# std     288.819436    26.456678     2.923431   11.706248   245.885335
# min       1.000000    10.080000     1.000000    0.508500    10.678500
# 25%     250.750000    32.875000     3.000000    5.833250   124.422375
# 50%     500.500000    55.230000     5.000000   12.072000   253.848000
# 75%     750.250000    77.690000     8.000000   22.428000   471.350250
# max    1000.000000    99.960000    10.000000   49.650000  1042.650000
#
#              cogs  gross_margin_percentage  gross_iincome      Rating
# count  1000.00000              1000.000000    1000.000000  1000.00000
# mean    307.58738                 4.761905      15.379369     6.97270
# std     234.17651                 0.000000      11.708825     1.71858
# ...

# %%
list(map(len,df.City))
# Out:
# [6,
#  9,
#  6,
#  6,
#  6,
#  9,
#  6,
#  9,
#  6,
#  8,
#  8,
#  8,
#  6,
#  6,
#  6,
#  8,
#  6,
#  6,
#  6,
#  8,
#  9,
#  8,
#  8,
#  6,
#  6,
#  6,
#  8,
#  6,
#  8,
#  6,
#  8,
#  8,
#  8,
#  6,
#  9,
#  9,
#  6,
#  6,
#  9,
#  8,
#  8,
#  9,
#  8,
#  9,
#  9,
#  8,
#  8,
#  8,
#  8,
#  9,
#  9,
#  6,
#  8,
#  9,
#  8,
#  9,
#  6,
#  6,
#  6,
#  9,
#  9,
#  9,
#  8,
#  6,
#  8,
#  6,
#  9,
#  8,
#  6,
#  6,
#  9,
#  9,
#  8,
#  9,
#  6,
#  9,
#  9,
#  6,
#  9,
#  9,
#  9,
#  8,
#  9,
#  9,
#  9,
#  9,
#  9,
#  6,
#  6,
#  8,
#  9,
#  9,
#  6,
#  8,
#  9,
#  6,
#  8,
#  9,
#  6,
#  8,
#  9,
#  9,
#  9,
#  6,
#  8,
#  6,
#  9,
#  6,
#  9,
#  9,
#  8,
#  9,
#  8,
#  6,
#  9,
#  9,
#  8,
#  8,
#  6,
#  8,
#  6,
#  9,
#  8,
#  9,
#  8,
#  6,
#  6,
#  9,
#  9,
#  8,
#  8,
#  6,
#  8,
#  8,
#  9,
#  9,
#  6,
#  6,
#  8,
#  6,
#  9,
#  9,
#  9,
#  9,
#  6,
#  9,
#  6,
#  9,
#  8,
#  6,
#  8,
#  9,
#  6,
#  9,
#  9,
#  6,
#  8,
#  8,
#  8,
#  8,
#  9,
#  6,
#  6,
#  9,
#  8,
#  8,
# ...

# %%
for j in df:
  if(np.dtype(df[j])=='int64' or np.dtype(df[j])=='float64'):
    m = df[j].mean()
    l = df.columns.get_loc(j)
    for i in range(len(df.Tax)):
      b = df.iloc[i,l]
      if(pd.isnull(df.iloc[i,l])):
        df.iloc[i,l]=m
