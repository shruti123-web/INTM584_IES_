# %% [markdown]
# <a href="https://colab.research.google.com/github/shruti123-web/INTM584_IES_/blob/main/INTM575_Lec2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/BostonHousing.csv')
df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
#linear relation
#Non-linear relation-> parabolic and exponential

# %%
#crim-> crime rate by town
#zn-> proportion of residential land zoned for iots over 25,000 sq.ft.
#INDUS-> proportion of non-retail business acres per town
#CHAS-> charles river dummy variable
#NOX-> nitric oxides concentration
#rm-> avg. no. of rooms per dwelling
#AGE-> proportion of owner-occupied unit built prior to 1940
#dis-> weighted distance to live Boston

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.isnull().sum(axis=0) #true ka sum lega, notnull mein bhi
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#df.indus.astype(str)

# %%
cor=df.iloc[:,:13].corr()
cor
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
cor1=df.iloc[:,[1,2,3,4,5,7,8]].corr()
cor1
# Out:
#              zn     indus      chas       nox        rm       dis       rad
# zn     1.000000 -0.533828 -0.042697 -0.516604  0.311991  0.664408 -0.311948
# indus -0.533828  1.000000  0.062938  0.763651 -0.391676 -0.708027  0.595129
# chas  -0.042697  0.062938  1.000000  0.091203  0.091251 -0.099176 -0.007368
# nox   -0.516604  0.763651  0.091203  1.000000 -0.302188 -0.769230  0.611441
# rm     0.311991 -0.391676  0.091251 -0.302188  1.000000  0.205246 -0.209847
# dis    0.664408 -0.708027 -0.099176 -0.769230  0.205246  1.000000 -0.494588
# rad   -0.311948  0.595129 -0.007368  0.611441 -0.209847 -0.494588  1.000000

# %%
##performance colours -> one colour shade -> red and green 
cor.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-41-145799562392>:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   cor.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_2bb15_row0_col0, #T_2bb15_row1_col1, #T_2bb15_row2_col2, #T_2bb15_row3_col3, #T_2bb15_row4_col4, #T_2bb15_row5_col5, #T_2bb15_row6_col6, #T_2bb15_row7_col7, #T_2bb15_row8_col8, #T_2bb15_row9_col9, #T_2bb15_row10_col10, #T_2bb15_row11_col11, #T_2bb15_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2bb15_row0_col1, #T_2bb15_row3_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_2bb15_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_2bb15_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_2bb15_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_2bb15_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_2bb15_row0_col6 {
# ...

# %%
import seaborn as sns
sns.pairplot(df.iloc[:,:7]) 
#class imbalance is chas (0 and 1)

# %%
import matplotlib.pyplot as plt
sns.heatmap(cor, square=True, cmap='YlGnBu') #cmap->color code
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
#!pip install SMOTE
#!pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#smote-> works on imbalanced data, overfitting, to make data balanced
#import imblearn
#oversample=SMOTE()

# %%
#R sq. doesn't take the overfitted values

# %%
#OLS method

# %%
#Adj R-squared
#adj R-squared value < R-square value 
#change more-> more overfitting

# %%
#overfiting occurs when in training data a variable is highly correlated but it is not the same in test data

# %%
#dep. variable should be normally distributed-> biasness hatt jaayegi

# %%
#scale-> log function or square root method or standard deviation

# %%
#VIF factor-> variance -> change in input variable will impact output variable, 1 se bade lenge hum

# %%
#variables-> raw data se related hai
#features-> modelling ke time jo select kare

# %%
#random_state-> random sampling karega split karne ke liye, generally 5 to 10

# %%
#x_test,x_train,y_train,y_test
